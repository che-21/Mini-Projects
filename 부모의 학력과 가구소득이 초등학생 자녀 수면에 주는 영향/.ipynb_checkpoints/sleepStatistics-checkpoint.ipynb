# %%
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt

# 1. 엑셀 파일 로드 및 전처리
df = pd.read_excel(
    './data/수면영향.xlsx', sheet_name='데이터', engine='openpyxl', header=[0, 1, 2]
)

# 2. 누락값(NaN)을 앞 데이터로 채움(엑셀 양식 병합 부분)
df.iloc[:, 0] = df.iloc[:, 0].ffill()

# 3. '모름/무응답' 행 제거하기
col_name = df.columns[1]
df = df[df[col_name] != '모름/무응답']

# 4. 숫자 데이터 변환
for col in df.columns[2:]:
  df[col] = pd.to_numeric(df[col], errors='coerce')

# 5. 5가지 카테고리 딕셔너리 생성
categories = {
    '성별': df[df.iloc[:, 0] == '성별'],
    '학력별(부)': df[df.iloc[:, 0] == '학력별(부)'],
    '학력별(모)': df[df.iloc[:, 0] == '학력별(모)'],
    '가구소득별': df[df.iloc[:, 0] == '가구소득별'],
    '시도별': df[df.iloc[:, 0] == '시도별'],
}

# 6. 순회하며 각각 출력
for name, sub_df in categories.items():
  print(f'[{name} 데이터]')

  styled_df = (
      sub_df.style.format(
          lambda x: f'{x:.1f}' if pd.notnull(x) else x,
          subset=sub_df.columns[3:],
      )
      .set_properties(**{'text-align': 'center'})
      .set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}])
  )

  display(styled_df)
  print('\n' + '=' * 60 + '\n')
# Out:
# [성별 데이터]
# <style type="text/css">
# #T_c8214 th {
#   text-align: center;
# }
# #T_c8214_row0_col0, #T_c8214_row0_col1, #T_c8214_row0_col2, #T_c8214_row0_col3, #T_c8214_row0_col4, #T_c8214_row0_col5, #T_c8214_row0_col6, #T_c8214_row0_col7, #T_c8214_row0_col8, #T_c8214_row0_col9, #T_c8214_row0_col10, #T_c8214_row0_col11, #T_c8214_row0_col12, #T_c8214_row0_col13, #T_c8214_row0_col14, #T_c8214_row1_col0, #T_c8214_row1_col1, #T_c8214_row1_col2, #T_c8214_row1_col3, #T_c8214_row1_col4, #T_c8214_row1_col5, #T_c8214_row1_col6, #T_c8214_row1_col7, #T_c8214_row1_col8, #T_c8214_row1_col9, #T_c8214_row1_col10, #T_c8214_row1_col11, #T_c8214_row1_col12, #T_c8214_row1_col13, #T_c8214_row1_col14 {
#   text-align: center;
# }
# </style>
# <table id="T_c8214">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8214_level0_col0" class="col_heading level0 col0" >특성별(1)</th>
#       <th id="T_c8214_level0_col1" class="col_heading level0 col1" >특성별(2)</th>
#       <th id="T_c8214_level0_col2" class="col_heading level0 col2" colspan="13">2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_c8214_level1_col0" class="col_heading level1 col0" >특성별(1)</th>
#       <th id="T_c8214_level1_col1" class="col_heading level1 col1" >특성별(2)</th>
#       <th id="T_c8214_level1_col2" class="col_heading level1 col2" >사례수 (명)</th>
#       <th id="T_c8214_level1_col3" class="col_heading level1 col3" colspan="4">평일 (%)</th>
#       <th id="T_c8214_level1_col7" class="col_heading level1 col7" colspan="2">평일(시)</th>
#       <th id="T_c8214_level1_col9" class="col_heading level1 col9" colspan="4">주말 (%)</th>
#       <th id="T_c8214_level1_col13" class="col_heading level1 col13" colspan="2">주말 (시)</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_c8214_level2_col0" class="col_heading level2 col0" >특성별(1)</th>
#       <th id="T_c8214_level2_col1" class="col_heading level2 col1" >특성별(2)</th>
#       <th id="T_c8214_level2_col2" class="col_heading level2 col2" >소계</th>
#       <th id="T_c8214_level2_col3" class="col_heading level2 col3" >매우 못 잔다</th>
#       <th id="T_c8214_level2_col4" class="col_heading level2 col4" >못 자는 편이다</th>
#       <th id="T_c8214_level2_col5" class="col_heading level2 col5" >잘 자는 편이다</th>
#       <th id="T_c8214_level2_col6" class="col_heading level2 col6" >매우 잘 잔다</th>
#       <th id="T_c8214_level2_col7" class="col_heading level2 col7" >취침시간</th>
#       <th id="T_c8214_level2_col8" class="col_heading level2 col8" >기상시간</th>
#       <th id="T_c8214_level2_col9" class="col_heading level2 col9" >매우 못 잔다</th>
#       <th id="T_c8214_level2_col10" class="col_heading level2 col10" >못 자는 편이다</th>
#       <th id="T_c8214_level2_col11" class="col_heading level2 col11" >잘 자는 편이다</th>
#       <th id="T_c8214_level2_col12" class="col_heading level2 col12" >매우 잘 잔다</th>
#       <th id="T_c8214_level2_col13" class="col_heading level2 col13" >취침시간</th>
#       <th id="T_c8214_level2_col14" class="col_heading level2 col14" >기상시간</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8214_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c8214_row0_col0" class="data row0 col0" >성별</td>
#       <td id="T_c8214_row0_col1" class="data row0 col1" >남자</td>
#       <td id="T_c8214_row0_col2" class="data row0 col2" >1092</td>
#       <td id="T_c8214_row0_col3" class="data row0 col3" >1.1</td>
#       <td id="T_c8214_row0_col4" class="data row0 col4" >18.8</td>
#       <td id="T_c8214_row0_col5" class="data row0 col5" >61.1</td>
#       <td id="T_c8214_row0_col6" class="data row0 col6" >19.0</td>
#       <td id="T_c8214_row0_col7" class="data row0 col7" >23.9</td>
#       <td id="T_c8214_row0_col8" class="data row0 col8" >6.9</td>
#       <td id="T_c8214_row0_col9" class="data row0 col9" >0.2</td>
#       <td id="T_c8214_row0_col10" class="data row0 col10" >5.4</td>
#       <td id="T_c8214_row0_col11" class="data row0 col11" >62.0</td>
#       <td id="T_c8214_row0_col12" class="data row0 col12" >32.4</td>
#       <td id="T_c8214_row0_col13" class="data row0 col13" >24.5</td>
#       <td id="T_c8214_row0_col14" class="data row0 col14" >9.0</td>
#     </tr>
#     <tr>
#       <th id="T_c8214_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c8214_row1_col0" class="data row1 col0" >성별</td>
#       <td id="T_c8214_row1_col1" class="data row1 col1" >여자</td>
#       <td id="T_c8214_row1_col2" class="data row1 col2" >1031</td>
#       <td id="T_c8214_row1_col3" class="data row1 col3" >1.1</td>
#       <td id="T_c8214_row1_col4" class="data row1 col4" >24.2</td>
#       <td id="T_c8214_row1_col5" class="data row1 col5" >56.7</td>
#       <td id="T_c8214_row1_col6" class="data row1 col6" >17.9</td>
#       <td id="T_c8214_row1_col7" class="data row1 col7" >24.1</td>
#       <td id="T_c8214_row1_col8" class="data row1 col8" >6.9</td>
#       <td id="T_c8214_row1_col9" class="data row1 col9" >0.5</td>
#       <td id="T_c8214_row1_col10" class="data row1 col10" >5.7</td>
#       <td id="T_c8214_row1_col11" class="data row1 col11" >61.0</td>
#       <td id="T_c8214_row1_col12" class="data row1 col12" >32.9</td>
#       <td id="T_c8214_row1_col13" class="data row1 col13" >24.5</td>
#       <td id="T_c8214_row1_col14" class="data row1 col14" >9.1</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#
# [학력별(부) 데이터]
# <style type="text/css">
# #T_08781 th {
#   text-align: center;
# }
# #T_08781_row0_col0, #T_08781_row0_col1, #T_08781_row0_col2, #T_08781_row0_col3, #T_08781_row0_col4, #T_08781_row0_col5, #T_08781_row0_col6, #T_08781_row0_col7, #T_08781_row0_col8, #T_08781_row0_col9, #T_08781_row0_col10, #T_08781_row0_col11, #T_08781_row0_col12, #T_08781_row0_col13, #T_08781_row0_col14, #T_08781_row1_col0, #T_08781_row1_col1, #T_08781_row1_col2, #T_08781_row1_col3, #T_08781_row1_col4, #T_08781_row1_col5, #T_08781_row1_col6, #T_08781_row1_col7, #T_08781_row1_col8, #T_08781_row1_col9, #T_08781_row1_col10, #T_08781_row1_col11, #T_08781_row1_col12, #T_08781_row1_col13, #T_08781_row1_col14, #T_08781_row2_col0, #T_08781_row2_col1, #T_08781_row2_col2, #T_08781_row2_col3, #T_08781_row2_col4, #T_08781_row2_col5, #T_08781_row2_col6, #T_08781_row2_col7, #T_08781_row2_col8, #T_08781_row2_col9, #T_08781_row2_col10, #T_08781_row2_col11, #T_08781_row2_col12, #T_08781_row2_col13, #T_08781_row2_col14 {
#   text-align: center;
# }
# </style>
# <table id="T_08781">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08781_level0_col0" class="col_heading level0 col0" >특성별(1)</th>
#       <th id="T_08781_level0_col1" class="col_heading level0 col1" >특성별(2)</th>
#       <th id="T_08781_level0_col2" class="col_heading level0 col2" colspan="13">2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_08781_level1_col0" class="col_heading level1 col0" >특성별(1)</th>
#       <th id="T_08781_level1_col1" class="col_heading level1 col1" >특성별(2)</th>
#       <th id="T_08781_level1_col2" class="col_heading level1 col2" >사례수 (명)</th>
#       <th id="T_08781_level1_col3" class="col_heading level1 col3" colspan="4">평일 (%)</th>
#       <th id="T_08781_level1_col7" class="col_heading level1 col7" colspan="2">평일(시)</th>
#       <th id="T_08781_level1_col9" class="col_heading level1 col9" colspan="4">주말 (%)</th>
#       <th id="T_08781_level1_col13" class="col_heading level1 col13" colspan="2">주말 (시)</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_08781_level2_col0" class="col_heading level2 col0" >특성별(1)</th>
#       <th id="T_08781_level2_col1" class="col_heading level2 col1" >특성별(2)</th>
#       <th id="T_08781_level2_col2" class="col_heading level2 col2" >소계</th>
#       <th id="T_08781_level2_col3" class="col_heading level2 col3" >매우 못 잔다</th>
#       <th id="T_08781_level2_col4" class="col_heading level2 col4" >못 자는 편이다</th>
#       <th id="T_08781_level2_col5" class="col_heading level2 col5" >잘 자는 편이다</th>
#       <th id="T_08781_level2_col6" class="col_heading level2 col6" >매우 잘 잔다</th>
#       <th id="T_08781_level2_col7" class="col_heading level2 col7" >취침시간</th>
#       <th id="T_08781_level2_col8" class="col_heading level2 col8" >기상시간</th>
#       <th id="T_08781_level2_col9" class="col_heading level2 col9" >매우 못 잔다</th>
#       <th id="T_08781_level2_col10" class="col_heading level2 col10" >못 자는 편이다</th>
#       <th id="T_08781_level2_col11" class="col_heading level2 col11" >잘 자는 편이다</th>
#       <th id="T_08781_level2_col12" class="col_heading level2 col12" >매우 잘 잔다</th>
#       <th id="T_08781_level2_col13" class="col_heading level2 col13" >취침시간</th>
#       <th id="T_08781_level2_col14" class="col_heading level2 col14" >기상시간</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08781_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_08781_row0_col0" class="data row0 col0" >학력별(부)</td>
#       <td id="T_08781_row0_col1" class="data row0 col1" >고졸 이하</td>
#       <td id="T_08781_row0_col2" class="data row0 col2" >463</td>
#       <td id="T_08781_row0_col3" class="data row0 col3" >1.4</td>
#       <td id="T_08781_row0_col4" class="data row0 col4" >22.8</td>
#       <td id="T_08781_row0_col5" class="data row0 col5" >55.6</td>
#       <td id="T_08781_row0_col6" class="data row0 col6" >20.2</td>
#       <td id="T_08781_row0_col7" class="data row0 col7" >23.9</td>
#       <td id="T_08781_row0_col8" class="data row0 col8" >7.0</td>
#       <td id="T_08781_row0_col9" class="data row0 col9" >0.7</td>
#       <td id="T_08781_row0_col10" class="data row0 col10" >5.9</td>
#       <td id="T_08781_row0_col11" class="data row0 col11" >57.6</td>
#       <td id="T_08781_row0_col12" class="data row0 col12" >35.8</td>
#       <td id="T_08781_row0_col13" class="data row0 col13" >24.5</td>
#       <td id="T_08781_row0_col14" class="data row0 col14" >9.2</td>
#     </tr>
#     <tr>
#       <th id="T_08781_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_08781_row1_col0" class="data row1 col0" >학력별(부)</td>
#       <td id="T_08781_row1_col1" class="data row1 col1" >대졸</td>
#       <td id="T_08781_row1_col2" class="data row1 col2" >1360</td>
#       <td id="T_08781_row1_col3" class="data row1 col3" >0.9</td>
#       <td id="T_08781_row1_col4" class="data row1 col4" >22.3</td>
#       <td id="T_08781_row1_col5" class="data row1 col5" >58.1</td>
#       <td id="T_08781_row1_col6" class="data row1 col6" >18.7</td>
#       <td id="T_08781_row1_col7" class="data row1 col7" >24.0</td>
#       <td id="T_08781_row1_col8" class="data row1 col8" >6.9</td>
#       <td id="T_08781_row1_col9" class="data row1 col9" >0.0</td>
#       <td id="T_08781_row1_col10" class="data row1 col10" >5.7</td>
#       <td id="T_08781_row1_col11" class="data row1 col11" >62.2</td>
#       <td id="T_08781_row1_col12" class="data row1 col12" >32.1</td>
#       <td id="T_08781_row1_col13" class="data row1 col13" >24.5</td>
#       <td id="T_08781_row1_col14" class="data row1 col14" >9.0</td>
#     </tr>
#     <tr>
#       <th id="T_08781_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_08781_row2_col0" class="data row2 col0" >학력별(부)</td>
#       <td id="T_08781_row2_col1" class="data row2 col1" >대학원졸 이상</td>
#       <td id="T_08781_row2_col2" class="data row2 col2" >220</td>
#       <td id="T_08781_row2_col3" class="data row2 col3" >2.0</td>
#       <td id="T_08781_row2_col4" class="data row2 col4" >15.5</td>
#       <td id="T_08781_row2_col5" class="data row2 col5" >67.9</td>
#       <td id="T_08781_row2_col6" class="data row2 col6" >14.6</td>
#       <td id="T_08781_row2_col7" class="data row2 col7" >24.1</td>
#       <td id="T_08781_row2_col8" class="data row2 col8" >6.9</td>
#       <td id="T_08781_row2_col9" class="data row2 col9" >1.5</td>
#       <td id="T_08781_row2_col10" class="data row2 col10" >5.0</td>
#       <td id="T_08781_row2_col11" class="data row2 col11" >63.4</td>
#       <td id="T_08781_row2_col12" class="data row2 col12" >30.0</td>
#       <td id="T_08781_row2_col13" class="data row2 col13" >24.5</td>
#       <td id="T_08781_row2_col14" class="data row2 col14" >9.0</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#
# [학력별(모) 데이터]
# <style type="text/css">
# #T_995e1 th {
#   text-align: center;
# }
# #T_995e1_row0_col0, #T_995e1_row0_col1, #T_995e1_row0_col2, #T_995e1_row0_col3, #T_995e1_row0_col4, #T_995e1_row0_col5, #T_995e1_row0_col6, #T_995e1_row0_col7, #T_995e1_row0_col8, #T_995e1_row0_col9, #T_995e1_row0_col10, #T_995e1_row0_col11, #T_995e1_row0_col12, #T_995e1_row0_col13, #T_995e1_row0_col14, #T_995e1_row1_col0, #T_995e1_row1_col1, #T_995e1_row1_col2, #T_995e1_row1_col3, #T_995e1_row1_col4, #T_995e1_row1_col5, #T_995e1_row1_col6, #T_995e1_row1_col7, #T_995e1_row1_col8, #T_995e1_row1_col9, #T_995e1_row1_col10, #T_995e1_row1_col11, #T_995e1_row1_col12, #T_995e1_row1_col13, #T_995e1_row1_col14, #T_995e1_row2_col0, #T_995e1_row2_col1, #T_995e1_row2_col2, #T_995e1_row2_col3, #T_995e1_row2_col4, #T_995e1_row2_col5, #T_995e1_row2_col6, #T_995e1_row2_col7, #T_995e1_row2_col8, #T_995e1_row2_col9, #T_995e1_row2_col10, #T_995e1_row2_col11, #T_995e1_row2_col12, #T_995e1_row2_col13, #T_995e1_row2_col14 {
#   text-align: center;
# }
# </style>
# <table id="T_995e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_995e1_level0_col0" class="col_heading level0 col0" >특성별(1)</th>
#       <th id="T_995e1_level0_col1" class="col_heading level0 col1" >특성별(2)</th>
#       <th id="T_995e1_level0_col2" class="col_heading level0 col2" colspan="13">2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_995e1_level1_col0" class="col_heading level1 col0" >특성별(1)</th>
#       <th id="T_995e1_level1_col1" class="col_heading level1 col1" >특성별(2)</th>
#       <th id="T_995e1_level1_col2" class="col_heading level1 col2" >사례수 (명)</th>
#       <th id="T_995e1_level1_col3" class="col_heading level1 col3" colspan="4">평일 (%)</th>
#       <th id="T_995e1_level1_col7" class="col_heading level1 col7" colspan="2">평일(시)</th>
#       <th id="T_995e1_level1_col9" class="col_heading level1 col9" colspan="4">주말 (%)</th>
#       <th id="T_995e1_level1_col13" class="col_heading level1 col13" colspan="2">주말 (시)</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_995e1_level2_col0" class="col_heading level2 col0" >특성별(1)</th>
#       <th id="T_995e1_level2_col1" class="col_heading level2 col1" >특성별(2)</th>
#       <th id="T_995e1_level2_col2" class="col_heading level2 col2" >소계</th>
#       <th id="T_995e1_level2_col3" class="col_heading level2 col3" >매우 못 잔다</th>
#       <th id="T_995e1_level2_col4" class="col_heading level2 col4" >못 자는 편이다</th>
#       <th id="T_995e1_level2_col5" class="col_heading level2 col5" >잘 자는 편이다</th>
#       <th id="T_995e1_level2_col6" class="col_heading level2 col6" >매우 잘 잔다</th>
#       <th id="T_995e1_level2_col7" class="col_heading level2 col7" >취침시간</th>
#       <th id="T_995e1_level2_col8" class="col_heading level2 col8" >기상시간</th>
#       <th id="T_995e1_level2_col9" class="col_heading level2 col9" >매우 못 잔다</th>
#       <th id="T_995e1_level2_col10" class="col_heading level2 col10" >못 자는 편이다</th>
#       <th id="T_995e1_level2_col11" class="col_heading level2 col11" >잘 자는 편이다</th>
#       <th id="T_995e1_level2_col12" class="col_heading level2 col12" >매우 잘 잔다</th>
#       <th id="T_995e1_level2_col13" class="col_heading level2 col13" >취침시간</th>
#       <th id="T_995e1_level2_col14" class="col_heading level2 col14" >기상시간</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_995e1_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_995e1_row0_col0" class="data row0 col0" >학력별(모)</td>
#       <td id="T_995e1_row0_col1" class="data row0 col1" >고졸 이하</td>
#       <td id="T_995e1_row0_col2" class="data row0 col2" >464</td>
#       <td id="T_995e1_row0_col3" class="data row0 col3" >0.4</td>
#       <td id="T_995e1_row0_col4" class="data row0 col4" >18.2</td>
#       <td id="T_995e1_row0_col5" class="data row0 col5" >60.2</td>
#       <td id="T_995e1_row0_col6" class="data row0 col6" >21.1</td>
#       <td id="T_995e1_row0_col7" class="data row0 col7" >23.9</td>
#       <td id="T_995e1_row0_col8" class="data row0 col8" >6.9</td>
#       <td id="T_995e1_row0_col9" class="data row0 col9" >0.5</td>
#       <td id="T_995e1_row0_col10" class="data row0 col10" >4.3</td>
#       <td id="T_995e1_row0_col11" class="data row0 col11" >58.3</td>
#       <td id="T_995e1_row0_col12" class="data row0 col12" >37.0</td>
#       <td id="T_995e1_row0_col13" class="data row0 col13" >24.5</td>
#       <td id="T_995e1_row0_col14" class="data row0 col14" >9.1</td>
#     </tr>
#     <tr>
#       <th id="T_995e1_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_995e1_row1_col0" class="data row1 col0" >학력별(모)</td>
#       <td id="T_995e1_row1_col1" class="data row1 col1" >대졸</td>
#       <td id="T_995e1_row1_col2" class="data row1 col2" >1449</td>
#       <td id="T_995e1_row1_col3" class="data row1 col3" >1.3</td>
#       <td id="T_995e1_row1_col4" class="data row1 col4" >22.3</td>
#       <td id="T_995e1_row1_col5" class="data row1 col5" >58.8</td>
#       <td id="T_995e1_row1_col6" class="data row1 col6" >17.7</td>
#       <td id="T_995e1_row1_col7" class="data row1 col7" >24.0</td>
#       <td id="T_995e1_row1_col8" class="data row1 col8" >6.9</td>
#       <td id="T_995e1_row1_col9" class="data row1 col9" >0.3</td>
#       <td id="T_995e1_row1_col10" class="data row1 col10" >5.4</td>
#       <td id="T_995e1_row1_col11" class="data row1 col11" >62.1</td>
#       <td id="T_995e1_row1_col12" class="data row1 col12" >32.2</td>
#       <td id="T_995e1_row1_col13" class="data row1 col13" >24.5</td>
#       <td id="T_995e1_row1_col14" class="data row1 col14" >9.0</td>
#     </tr>
#     <tr>
#       <th id="T_995e1_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_995e1_row2_col0" class="data row2 col0" >학력별(모)</td>
#       <td id="T_995e1_row2_col1" class="data row2 col1" >대학원졸 이상</td>
#       <td id="T_995e1_row2_col2" class="data row2 col2" >178</td>
#       <td id="T_995e1_row2_col3" class="data row2 col3" >1.2</td>
#       <td id="T_995e1_row2_col4" class="data row2 col4" >22.7</td>
#       <td id="T_995e1_row2_col5" class="data row2 col5" >57.2</td>
#       <td id="T_995e1_row2_col6" class="data row2 col6" >18.9</td>
#       <td id="T_995e1_row2_col7" class="data row2 col7" >24.1</td>
#       <td id="T_995e1_row2_col8" class="data row2 col8" >6.9</td>
#       <td id="T_995e1_row2_col9" class="data row2 col9" >0.4</td>
#       <td id="T_995e1_row2_col10" class="data row2 col10" >8.5</td>
#       <td id="T_995e1_row2_col11" class="data row2 col11" >66.4</td>
#       <td id="T_995e1_row2_col12" class="data row2 col12" >24.7</td>
#       <td id="T_995e1_row2_col13" class="data row2 col13" >24.7</td>
#       <td id="T_995e1_row2_col14" class="data row2 col14" >9.0</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#
# [가구소득별 데이터]
# <style type="text/css">
# #T_1ad7a th {
#   text-align: center;
# }
# #T_1ad7a_row0_col0, #T_1ad7a_row0_col1, #T_1ad7a_row0_col2, #T_1ad7a_row0_col3, #T_1ad7a_row0_col4, #T_1ad7a_row0_col5, #T_1ad7a_row0_col6, #T_1ad7a_row0_col7, #T_1ad7a_row0_col8, #T_1ad7a_row0_col9, #T_1ad7a_row0_col10, #T_1ad7a_row0_col11, #T_1ad7a_row0_col12, #T_1ad7a_row0_col13, #T_1ad7a_row0_col14, #T_1ad7a_row1_col0, #T_1ad7a_row1_col1, #T_1ad7a_row1_col2, #T_1ad7a_row1_col3, #T_1ad7a_row1_col4, #T_1ad7a_row1_col5, #T_1ad7a_row1_col6, #T_1ad7a_row1_col7, #T_1ad7a_row1_col8, #T_1ad7a_row1_col9, #T_1ad7a_row1_col10, #T_1ad7a_row1_col11, #T_1ad7a_row1_col12, #T_1ad7a_row1_col13, #T_1ad7a_row1_col14, #T_1ad7a_row2_col0, #T_1ad7a_row2_col1, #T_1ad7a_row2_col2, #T_1ad7a_row2_col3, #T_1ad7a_row2_col4, #T_1ad7a_row2_col5, #T_1ad7a_row2_col6, #T_1ad7a_row2_col7, #T_1ad7a_row2_col8, #T_1ad7a_row2_col9, #T_1ad7a_row2_col10, #T_1ad7a_row2_col11, #T_1ad7a_row2_col12, #T_1ad7a_row2_col13, #T_1ad7a_row2_col14, #T_1ad7a_row3_col0, #T_1ad7a_row3_col1, #T_1ad7a_row3_col2, #T_1ad7a_row3_col3, #T_1ad7a_row3_col4, #T_1ad7a_row3_col5, #T_1ad7a_row3_col6, #T_1ad7a_row3_col7, #T_1ad7a_row3_col8, #T_1ad7a_row3_col9, #T_1ad7a_row3_col10, #T_1ad7a_row3_col11, #T_1ad7a_row3_col12, #T_1ad7a_row3_col13, #T_1ad7a_row3_col14, #T_1ad7a_row4_col0, #T_1ad7a_row4_col1, #T_1ad7a_row4_col2, #T_1ad7a_row4_col3, #T_1ad7a_row4_col4, #T_1ad7a_row4_col5, #T_1ad7a_row4_col6, #T_1ad7a_row4_col7, #T_1ad7a_row4_col8, #T_1ad7a_row4_col9, #T_1ad7a_row4_col10, #T_1ad7a_row4_col11, #T_1ad7a_row4_col12, #T_1ad7a_row4_col13, #T_1ad7a_row4_col14, #T_1ad7a_row5_col0, #T_1ad7a_row5_col1, #T_1ad7a_row5_col2, #T_1ad7a_row5_col3, #T_1ad7a_row5_col4, #T_1ad7a_row5_col5, #T_1ad7a_row5_col6, #T_1ad7a_row5_col7, #T_1ad7a_row5_col8, #T_1ad7a_row5_col9, #T_1ad7a_row5_col10, #T_1ad7a_row5_col11, #T_1ad7a_row5_col12, #T_1ad7a_row5_col13, #T_1ad7a_row5_col14 {
#   text-align: center;
# }
# </style>
# <table id="T_1ad7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ad7a_level0_col0" class="col_heading level0 col0" >특성별(1)</th>
#       <th id="T_1ad7a_level0_col1" class="col_heading level0 col1" >특성별(2)</th>
#       <th id="T_1ad7a_level0_col2" class="col_heading level0 col2" colspan="13">2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_1ad7a_level1_col0" class="col_heading level1 col0" >특성별(1)</th>
#       <th id="T_1ad7a_level1_col1" class="col_heading level1 col1" >특성별(2)</th>
#       <th id="T_1ad7a_level1_col2" class="col_heading level1 col2" >사례수 (명)</th>
#       <th id="T_1ad7a_level1_col3" class="col_heading level1 col3" colspan="4">평일 (%)</th>
#       <th id="T_1ad7a_level1_col7" class="col_heading level1 col7" colspan="2">평일(시)</th>
#       <th id="T_1ad7a_level1_col9" class="col_heading level1 col9" colspan="4">주말 (%)</th>
#       <th id="T_1ad7a_level1_col13" class="col_heading level1 col13" colspan="2">주말 (시)</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_1ad7a_level2_col0" class="col_heading level2 col0" >특성별(1)</th>
#       <th id="T_1ad7a_level2_col1" class="col_heading level2 col1" >특성별(2)</th>
#       <th id="T_1ad7a_level2_col2" class="col_heading level2 col2" >소계</th>
#       <th id="T_1ad7a_level2_col3" class="col_heading level2 col3" >매우 못 잔다</th>
#       <th id="T_1ad7a_level2_col4" class="col_heading level2 col4" >못 자는 편이다</th>
#       <th id="T_1ad7a_level2_col5" class="col_heading level2 col5" >잘 자는 편이다</th>
#       <th id="T_1ad7a_level2_col6" class="col_heading level2 col6" >매우 잘 잔다</th>
#       <th id="T_1ad7a_level2_col7" class="col_heading level2 col7" >취침시간</th>
#       <th id="T_1ad7a_level2_col8" class="col_heading level2 col8" >기상시간</th>
#       <th id="T_1ad7a_level2_col9" class="col_heading level2 col9" >매우 못 잔다</th>
#       <th id="T_1ad7a_level2_col10" class="col_heading level2 col10" >못 자는 편이다</th>
#       <th id="T_1ad7a_level2_col11" class="col_heading level2 col11" >잘 자는 편이다</th>
#       <th id="T_1ad7a_level2_col12" class="col_heading level2 col12" >매우 잘 잔다</th>
#       <th id="T_1ad7a_level2_col13" class="col_heading level2 col13" >취침시간</th>
#       <th id="T_1ad7a_level2_col14" class="col_heading level2 col14" >기상시간</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ad7a_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_1ad7a_row0_col0" class="data row0 col0" >가구소득별</td>
#       <td id="T_1ad7a_row0_col1" class="data row0 col1" >100만원 미만</td>
#       <td id="T_1ad7a_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_1ad7a_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_1ad7a_row0_col4" class="data row0 col4" >14.0</td>
#       <td id="T_1ad7a_row0_col5" class="data row0 col5" >78.5</td>
#       <td id="T_1ad7a_row0_col6" class="data row0 col6" >7.6</td>
#       <td id="T_1ad7a_row0_col7" class="data row0 col7" >23.9</td>
#       <td id="T_1ad7a_row0_col8" class="data row0 col8" >7.1</td>
#       <td id="T_1ad7a_row0_col9" class="data row0 col9" >0.0</td>
#       <td id="T_1ad7a_row0_col10" class="data row0 col10" >15.0</td>
#       <td id="T_1ad7a_row0_col11" class="data row0 col11" >67.6</td>
#       <td id="T_1ad7a_row0_col12" class="data row0 col12" >17.4</td>
#       <td id="T_1ad7a_row0_col13" class="data row0 col13" >24.6</td>
#       <td id="T_1ad7a_row0_col14" class="data row0 col14" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_1ad7a_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_1ad7a_row1_col0" class="data row1 col0" >가구소득별</td>
#       <td id="T_1ad7a_row1_col1" class="data row1 col1" >100~200만원 미만</td>
#       <td id="T_1ad7a_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_1ad7a_row1_col3" class="data row1 col3" >5.7</td>
#       <td id="T_1ad7a_row1_col4" class="data row1 col4" >25.4</td>
#       <td id="T_1ad7a_row1_col5" class="data row1 col5" >61.9</td>
#       <td id="T_1ad7a_row1_col6" class="data row1 col6" >7.0</td>
#       <td id="T_1ad7a_row1_col7" class="data row1 col7" >24.6</td>
#       <td id="T_1ad7a_row1_col8" class="data row1 col8" >7.0</td>
#       <td id="T_1ad7a_row1_col9" class="data row1 col9" >0.0</td>
#       <td id="T_1ad7a_row1_col10" class="data row1 col10" >4.1</td>
#       <td id="T_1ad7a_row1_col11" class="data row1 col11" >69.5</td>
#       <td id="T_1ad7a_row1_col12" class="data row1 col12" >26.4</td>
#       <td id="T_1ad7a_row1_col13" class="data row1 col13" >25.2</td>
#       <td id="T_1ad7a_row1_col14" class="data row1 col14" >9.8</td>
#     </tr>
#     <tr>
#       <th id="T_1ad7a_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_1ad7a_row2_col0" class="data row2 col0" >가구소득별</td>
#       <td id="T_1ad7a_row2_col1" class="data row2 col1" >200~300만원 미만</td>
#       <td id="T_1ad7a_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_1ad7a_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_1ad7a_row2_col4" class="data row2 col4" >14.3</td>
#       <td id="T_1ad7a_row2_col5" class="data row2 col5" >62.0</td>
#       <td id="T_1ad7a_row2_col6" class="data row2 col6" >23.7</td>
#       <td id="T_1ad7a_row2_col7" class="data row2 col7" >23.7</td>
#       <td id="T_1ad7a_row2_col8" class="data row2 col8" >6.9</td>
#       <td id="T_1ad7a_row2_col9" class="data row2 col9" >0.0</td>
#       <td id="T_1ad7a_row2_col10" class="data row2 col10" >8.7</td>
#       <td id="T_1ad7a_row2_col11" class="data row2 col11" >49.9</td>
#       <td id="T_1ad7a_row2_col12" class="data row2 col12" >41.4</td>
#       <td id="T_1ad7a_row2_col13" class="data row2 col13" >24.4</td>
#       <td id="T_1ad7a_row2_col14" class="data row2 col14" >8.9</td>
#     </tr>
#     <tr>
#       <th id="T_1ad7a_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_1ad7a_row3_col0" class="data row3 col0" >가구소득별</td>
#       <td id="T_1ad7a_row3_col1" class="data row3 col1" >300~400만원 미만</td>
#       <td id="T_1ad7a_row3_col2" class="data row3 col2" >171</td>
#       <td id="T_1ad7a_row3_col3" class="data row3 col3" >0.9</td>
#       <td id="T_1ad7a_row3_col4" class="data row3 col4" >14.6</td>
#       <td
# ============================================================
#
# [시도별 데이터]
# <style type="text/css">
# #T_c3881 th {
#   text-align: center;
# }
# #T_c3881_row0_col0, #T_c3881_row0_col1, #T_c3881_row0_col2, #T_c3881_row0_col3, #T_c3881_row0_col4, #T_c3881_row0_col5, #T_c3881_row0_col6, #T_c3881_row0_col7, #T_c3881_row0_col8, #T_c3881_row0_col9, #T_c3881_row0_col10, #T_c3881_row0_col11, #T_c3881_row0_col12, #T_c3881_row0_col13, #T_c3881_row0_col14, #T_c3881_row1_col0, #T_c3881_row1_col1, #T_c3881_row1_col2, #T_c3881_row1_col3, #T_c3881_row1_col4, #T_c3881_row1_col5, #T_c3881_row1_col6, #T_c3881_row1_col7, #T_c3881_row1_col8, #T_c3881_row1_col9, #T_c3881_row1_col10, #T_c3881_row1_col11, #T_c3881_row1_col12, #T_c3881_row1_col13, #T_c3881_row1_col14, #T_c3881_row2_col0, #T_c3881_row2_col1, #T_c3881_row2_col2, #T_c3881_row2_col3, #T_c3881_row2_col4, #T_c3881_row2_col5, #T_c3881_row2_col6, #T_c3881_row2_col7, #T_c3881_row2_col8, #T_c3881_row2_col9, #T_c3881_row2_col10, #T_c3881_row2_col11, #T_c3881_row2_col12, #T_c3881_row2_col13, #T_c3881_row2_col14, #T_c3881_row3_col0, #T_c3881_row3_col1, #T_c3881_row3_col2, #T_c3881_row3_col3, #T_c3881_row3_col4, #T_c3881_row3_col5, #T_c3881_row3_col6, #T_c3881_row3_col7, #T_c3881_row3_col8, #T_c3881_row3_col9, #T_c3881_row3_col10, #T_c3881_row3_col11, #T_c3881_row3_col12, #T_c3881_row3_col13, #T_c3881_row3_col14, #T_c3881_row4_col0, #T_c3881_row4_col1, #T_c3881_row4_col2, #T_c3881_row4_col3, #T_c3881_row4_col4, #T_c3881_row4_col5, #T_c3881_row4_col6, #T_c3881_row4_col7, #T_c3881_row4_col8, #T_c3881_row4_col9, #T_c3881_row4_col10, #T_c3881_row4_col11, #T_c3881_row4_col12, #T_c3881_row4_col13, #T_c3881_row4_col14, #T_c3881_row5_col0, #T_c3881_row5_col1, #T_c3881_row5_col2, #T_c3881_row5_col3, #T_c3881_row5_col4, #T_c3881_row5_col5, #T_c3881_row5_col6, #T_c3881_row5_col7, #T_c3881_row5_col8, #T_c3881_row5_col9, #T_c3881_row5_col10, #T_c3881_row5_col11, #T_c3881_row5_col12, #T_c3881_row5_col13, #T_c3881_row5_col14, #T_c3881_row6_col0, #T_c3881_row6_col1, #T_c3881_row6_col2, #T_c3881_row6_col3, #T_c3881_row6_col4, #T_c3881_row6_col5, #T_c3881_row6_col6, #T_c3881_row6_col7, #T_c3881_row6_col8, #T_c3881_row6_col9, #T_c3881_row6_col10, #T_c3881_row6_col11, #T_c3881_row6_col12, #T_c3881_row6_col13, #T_c3881_row6_col14, #T_c3881_row7_col0, #T_c3881_row7_col1, #T_c3881_row7_col2, #T_c3881_row7_col3, #T_c3881_row7_col4, #T_c3881_row7_col5, #T_c3881_row7_col6, #T_c3881_row7_col7, #T_c3881_row7_col8, #T_c3881_row7_col9, #T_c3881_row7_col10, #T_c3881_row7_col11, #T_c3881_row7_col12, #T_c3881_row7_col13, #T_c3881_row7_col14, #T_c3881_row8_col0, #T_c3881_row8_col1, #T_c3881_row8_col2, #T_c3881_row8_col3, #T_c3881_row8_col4, #T_c3881_row8_col5, #T_c3881_row8_col6, #T_c3881_row8_col7, #T_c3881_row8_col8, #T_c3881_row8_col9, #T_c3881_row8_col10, #T_c3881_row8_col11, #T_c3881_row8_col12, #T_c3881_row8_col13, #T_c3881_row8_col14, #T_c3881_row9_col0, #T_c3881_row9_col1, #T_c3881_row9_col2, #T_c3881_row9_col3, #T_c3881_row9_col4, #T_c3881_row9_col5, #T_c3881_row9_col6, #T_c3881_row9_col7, #T_c3881_row9_col8, #T_c3881_row9_col9, #T_c3881_row9_col10, #T_c3881_row9_col11, #T_c3881_row9_col12, #T_c3881_row9_col13, #T_c3881_row9_col14, #T_c3881_row10_col0, #T_c3881_row10_col1, #T_c3881_row10_col2, #T_c3881_row10_col3, #T_c3881_row10_col4, #T_c3881_row10_col5, #T_c3881_row10_col6, #T_c3881_row10_col7, #T_c3881_row10_col8, #T_c3881_row10_col9, #T_c3881_row10_col10, #T_c3881_row10_col11, #T_c3881_row10_col12, #T_c3881_row10_col13, #T_c3881_row10_col14, #T_c3881_row11_col0, #T_c3881_row11_col1, #T_c3881_row11_col2, #T_c3881_row11_col3, #T_c3881_row11_col4, #T_c3881_row11_col5, #T_c3881_row11_col6, #T_c3881_row11_col7, #T_c3881_row11_col8, #T_c3881_row11_col9, #T_c3881_row11_col10, #T_c3881_row11_col11, #T_c3881_row11_col12, #T_c3881_row11_col13, #T_c3881_row11_col14, #T_c3881_row12_col0, #T_c3881_row12_col1, #T_c3881_row12_col2, #T_c3881_row12_col3, #T_c3881_row12_col4, #T_c3881_row12_col5, #T_c3881_row12_col6, #T_c3881_row12_col7, #T_c3881_row12_col8, #T_c3881_row12_col9, #T_c3881_row12_col10, #T_c3881_row12_col11, #T_c3881_row12_col12, #T_c3881_row12_col13, #T_c3881_row ...
#   text-align: center;
# }
# </style>
# <table id="T_c3881">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3881_level0_col0" class="col_heading level0 col0" >특성별(1)</th>
#       <th id="T_c3881_level0_col1" class="col_heading level0 col1" >특성별(2)</th>
#       <th id="T_c3881_level0_col2" class="col_heading level0 col2" colspan="13">2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_c3881_level1_col0" class="col_heading level1 col0" >특성별(1)</th>
#       <th id="T_c3881_level1_col1" class="col_heading level1 col1" >특성별(2)</th>
#       <th id="T_c3881_level1_col2" class="col_heading level1 col2" >사례수 (명)</th>
#       <th id="T_c3881_level1_col3" class="col_heading level1 col3" colspan="4">평일 (%)</th>
#       <th id="T_c3881_level1_col7" class="col_heading level1 col7" colspan="2">평일(시)</th>
#       <th id="T_c3881_level1_col9" class="col_heading level1 col9" colspan="4">주말 (%)</th>
#       <th id="T_c3881_level1_col13" class="col_heading level1 col13" colspan="2">주말 (시)</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_c3881_level2_col0" class="col_heading level2 col0" >특성별(1)</th>
#       <th id="T_c3881_level2_col1" class="col_heading level2 col1" >특성별(2)</th>
#       <th id="T_c3881_level2_col2" class="col_heading level2 col2" >소계</th>
#       <th id="T_c3881_level2_col3" class="col_heading level2 col3" >매우 못 잔다</th>
#       <th id="T_c3881_level2_col4" class="col_heading level2 col4" >못 자는 편이다</th>
#       <th id="T_c3881_level2_col5" class="col_heading level2 col5" >잘 자는 편이다</th>
#       <th id="T_c3881_level2_col6" class="col_heading level2 col6" >매우 잘 잔다</th>
#       <th id="T_c3881_level2_col7" class="col_heading level2 col7" >취침시간</th>
#       <th id="T_c3881_level2_col8" class="col_heading level2 col8" >기상시간</th>
#       <th id="T_c3881_level2_col9" class="col_heading level2 col9" >매우 못 잔다</th>
#       <th id="T_c3881_level2_col10" class="col_heading level2 col10" >못 자는 편이다</th>
#       <th id="T_c3881_level2_col11" class="col_heading level2 col11" >잘 자는 편이다</th>
#       <th id="T_c3881_level2_col12" class="col_heading level2 col12" >매우 잘 잔다</th>
#       <th id="T_c3881_level2_col13" class="col_heading level2 col13" >취침시간</th>
#       <th id="T_c3881_level2_col14" class="col_heading level2 col14" >기상시간</th>
#     </tr>
#   </thea
# ============================================================

# %%
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt


# ====================================================
# 엑셀 데이터 로드 및 테이블 출력
# ====================================================
# 전처리
# (1) 한글 폰트 설정 (Windows 기준)
plt.rc('font', family='Malgun Gothic')

# (2) 마이너스 기호 깨짐 방지
plt.rc('axes', unicode_minus=False)

# 1. 엑셀 파일 로드 
df = pd.read_excel(
    './data/수면영향.xlsx', sheet_name='데이터', engine='openpyxl', header=[0, 1, 2]
)

# 2. 누락값(NaN)을 앞 데이터로 채움(엑셀 양식 병합 부분)
df.iloc[:, 0] = df.iloc[:, 0].ffill()

# 3. 숫자 데이터 변환
for col in df.columns[2:]:
  df[col] = pd.to_numeric(df[col], errors='coerce')

# ----------------------------------------------------
# 성별 데이터 필터링 및 컬럼 정의
# ----------------------------------------------------
name = '성별'
sub_df = df[df.iloc[:, 0] == name].copy()

# 평일 만족도(컬럼 3~6) 및 주말 만족도(컬럼 9~12)
target_cols = list(df.columns[3:7]) + list(df.columns[9:13])

# 4. 데이터 표 출력
print(f'[{name} 데이터]')

styled_df = (
    sub_df.style.format(
        {
            sub_df.columns[2]: '{:.0f}',  # 사례수(소계) : 소수점 없이 정수로 표시
        },
        na_rep='',
    )
    .format(
        lambda x: f'{x:.1f}' if pd.notnull(x) else x,
        subset=sub_df.columns[3:],  # 비율 및 수면시간 : 소수점 첫째 자리까지 표시
    )
    .set_properties(**{'text-align': 'center'})
    .set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}])
)

display(styled_df)


# ====================================================
# 그래프 그리기
# ====================================================
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ----------------------------------------------------
# [1] 평일: 수면 만족도 (막대) + 수면시간 (꺾은선)
# ----------------------------------------------------
# (1) 막대그래프 (왼쪽 Y축: 비율 %)
df_weekday = sub_df[target_cols[:4]].copy()
df_weekday.columns = ['매우 못 잔다', '못 자는 편이다', '잘 자는 편이다', '매우 잘 잔다']
df_weekday.index = sub_df.iloc[:, 1]
df_weekday.index.name = None

df_weekday.T[['여자', '남자']].plot(
    kind='bar', ax=axes[0], color=['#800014', '#3C4EC2'], rot=0, width=0.6
)
axes[0].set_title('평일 수면 만족도 및 수면시간', fontsize=13, fontweight='bold')
axes[0].set_ylabel('만족도 비율 (%)')
axes[0].set_ylim(0, 80)

# (2) 꺾은선그래프 (오른쪽 Y축: 수면시간)
ax0_twin = axes[0].twinx()

# 표 기준 평일 수면시간(기상-취침 계산값 등)
female_sleep_wk = 6.8
male_sleep_wk = 7.0

# 막대 위치(x축 인덱스 0~3)에 맞춰 꺾은선 배치
ax0_twin.plot([0, 1, 2, 3], [female_sleep_wk]*4, color='#e74c3c', marker='o', linestyle='--', label='여자 수면시간')
ax0_twin.plot([0, 1, 2, 3], [male_sleep_wk]*4, color='#2980b9', marker='s', linestyle='--', label='남자 수면시간')

ax0_twin.set_ylabel('평균 수면시간 (시간)')
ax0_twin.set_ylim(4, 10) # 수면시간 범위에 맞춰 조정

# ----------------------------------------------------
# [2] 주말: 수면 만족도 (막대) + 수면시간 (꺾은선)
# ----------------------------------------------------
# (1) 막대그래프 (왼쪽 Y축: 비율 %)
df_weekend = sub_df[target_cols[4:]].copy()
df_weekend.columns = ['매우 못 잔다', '못 자는 편이다', '잘 자는 편이다', '매우 잘 잔다']
df_weekend.index = sub_df.iloc[:, 1]
df_weekend.index.name = None

df_weekend.T[['여자', '남자']].plot(
    kind='bar', ax=axes[1], color=['#800014', '#3C4EC2'], rot=0, width=0.6
)
axes[1].set_title('주말 수면 만족도 및 수면시간', fontsize=13, fontweight='bold')
axes[1].set_ylabel('만족도 비율 (%)')
axes[1].set_ylim(0, 80)

# (2) 꺾은선그래프 (오른쪽 Y축: 수면시간)
ax1_twin = axes[1].twinx()

female_sleep_we = 8.6
male_sleep_we = 8.5

ax1_twin.plot([0, 1, 2, 3], [female_sleep_we]*4, color='#e74c3c', marker='o', linestyle='--', label='여자 수면시간')
ax1_twin.plot([0, 1, 2, 3], [male_sleep_we]*4, color='#2980b9', marker='s', linestyle='--', label='남자 수면시간')

ax1_twin.set_ylabel('평균 수면시간 (시간)')
ax1_twin.set_ylim(4, 10)

plt.tight_layout()
plt.show()
# Out:
# [성별 데이터]
# <style type="text/css">
# #T_08daf th {
#   text-align: center;
# }
# #T_08daf_row0_col0, #T_08daf_row0_col1, #T_08daf_row0_col2, #T_08daf_row0_col3, #T_08daf_row0_col4, #T_08daf_row0_col5, #T_08daf_row0_col6, #T_08daf_row0_col7, #T_08daf_row0_col8, #T_08daf_row0_col9, #T_08daf_row0_col10, #T_08daf_row0_col11, #T_08daf_row0_col12, #T_08daf_row0_col13, #T_08daf_row0_col14, #T_08daf_row1_col0, #T_08daf_row1_col1, #T_08daf_row1_col2, #T_08daf_row1_col3, #T_08daf_row1_col4, #T_08daf_row1_col5, #T_08daf_row1_col6, #T_08daf_row1_col7, #T_08daf_row1_col8, #T_08daf_row1_col9, #T_08daf_row1_col10, #T_08daf_row1_col11, #T_08daf_row1_col12, #T_08daf_row1_col13, #T_08daf_row1_col14 {
#   text-align: center;
# }
# </style>
# <table id="T_08daf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08daf_level0_col0" class="col_heading level0 col0" >특성별(1)</th>
#       <th id="T_08daf_level0_col1" class="col_heading level0 col1" >특성별(2)</th>
#       <th id="T_08daf_level0_col2" class="col_heading level0 col2" colspan="13">2024</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_08daf_level1_col0" class="col_heading level1 col0" >특성별(1)</th>
#       <th id="T_08daf_level1_col1" class="col_heading level1 col1" >특성별(2)</th>
#       <th id="T_08daf_level1_col2" class="col_heading level1 col2" >사례수 (명)</th>
#       <th id="T_08daf_level1_col3" class="col_heading level1 col3" colspan="4">평일 (%)</th>
#       <th id="T_08daf_level1_col7" class="col_heading level1 col7" colspan="2">평일(시)</th>
#       <th id="T_08daf_level1_col9" class="col_heading level1 col9" colspan="4">주말 (%)</th>
#       <th id="T_08daf_level1_col13" class="col_heading level1 col13" colspan="2">주말 (시)</th>
#     </tr>
#     <tr>
#       <th class="blank level2" >&nbsp;</th>
#       <th id="T_08daf_level2_col0" class="col_heading level2 col0" >특성별(1)</th>
#       <th id="T_08daf_level2_col1" class="col_heading level2 col1" >특성별(2)</th>
#       <th id="T_08daf_level2_col2" class="col_heading level2 col2" >소계</th>
#       <th id="T_08daf_level2_col3" class="col_heading level2 col3" >매우 못 잔다</th>
#       <th id="T_08daf_level2_col4" class="col_heading level2 col4" >못 자는 편이다</th>
#       <th id="T_08daf_level2_col5" class="col_heading level2 col5" >잘 자는 편이다</th>
#       <th id="T_08daf_level2_col6" class="col_heading level2 col6" >매우 잘 잔다</th>
#       <th id="T_08daf_level2_col7" class="col_heading level2 col7" >취침시간</th>
#       <th id="T_08daf_level2_col8" class="col_heading level2 col8" >기상시간</th>
#       <th id="T_08daf_level2_col9" class="col_heading level2 col9" >매우 못 잔다</th>
#       <th id="T_08daf_level2_col10" class="col_heading level2 col10" >못 자는 편이다</th>
#       <th id="T_08daf_level2_col11" class="col_heading level2 col11" >잘 자는 편이다</th>
#       <th id="T_08daf_level2_col12" class="col_heading level2 col12" >매우 잘 잔다</th>
#       <th id="T_08daf_level2_col13" class="col_heading level2 col13" >취침시간</th>
#       <th id="T_08daf_level2_col14" class="col_heading level2 col14" >기상시간</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08daf_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_08daf_row0_col0" class="data row0 col0" >성별</td>
#       <td id="T_08daf_row0_col1" class="data row0 col1" >남자</td>
#       <td id="T_08daf_row0_col2" class="data row0 col2" >1092</td>
#       <td id="T_08daf_row0_col3" class="data row0 col3" >1.1</td>
#       <td id="T_08daf_row0_col4" class="data row0 col4" >18.8</td>
#       <td id="T_08daf_row0_col5" class="data row0 col5" >61.1</td>
#       <td id="T_08daf_row0_col6" class="data row0 col6" >19.0</td>
#       <td id="T_08daf_row0_col7" class="data row0 col7" >23.9</td>
#       <td id="T_08daf_row0_col8" class="data row0 col8" >6.9</td>
#       <td id="T_08daf_row0_col9" class="data row0 col9" >0.2</td>
#       <td id="T_08daf_row0_col10" class="data row0 col10" >5.4</td>
#       <td id="T_08daf_row0_col11" class="data row0 col11" >62.0</td>
#       <td id="T_08daf_row0_col12" class="data row0 col12" >32.4</td>
#       <td id="T_08daf_row0_col13" class="data row0 col13" >24.5</td>
#       <td id="T_08daf_row0_col14" class="data row0 col14" >9.0</td>
#     </tr>
#     <tr>
#       <th id="T_08daf_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_08daf_row1_col0" class="data row1 col0" >성별</td>
#       <td id="T_08daf_row1_col1" class="data row1 col1" >여자</td>
#       <td id="T_08daf_row1_col2" class="data row1 col2" >1031</td>
#       <td id="T_08daf_row1_col3" class="data row1 col3" >1.1</td>
#       <td id="T_08daf_row1_col4" class="data row1 col4" >24.2</td>
#       <td id="T_08daf_row1_col5" class="data row1 col5" >56.7</td>
#       <td id="T_08daf_row1_col6" class="data row1 col6" >17.9</td>
#       <td id="T_08daf_row1_col7" class="data row1 col7" >24.1</td>
#       <td id="T_08daf_row1_col8" class="data row1 col8" >6.9</td>
#       <td id="T_08daf_row1_col9" class="data row1 col9" >0.5</td>
#       <td id="T_08daf_row1_col10" class="data row1 col10" >5.7</td>
#       <td id="T_08daf_row1_col11" class="data row1 col11" >61.0</td>
#       <td id="T_08daf_row1_col12" class="data row1 col12" >32.9</td>
#       <td id="T_08daf_row1_col13" class="data row1 col13" >24.5</td>
#       <td id="T_08daf_row1_col14" class="data row1 col14" >9.1</td>
#     </tr>
#   </tbody>
# </table>
